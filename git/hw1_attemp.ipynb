# %% [markdown]
# This is my attempt on the first homework for FFR120.

# %%
# We will write in Julia
using Random
using LinearAlgebra
using Plots

a = 23
@printf "Hello %s" a
# Out:
# Hello 23

# %% [markdown]
# ### Part 1 -
